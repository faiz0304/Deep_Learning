# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Churn_Modelling.csv")
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
dataset = df.iloc[:,1:]

# %%
dataset.head(3)
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
#
#    Exited
# 0       1
# 1       0
# 2       1

# %%
dataset.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
input_data = dataset.iloc[:,:-1]
ouptut_data = dataset.iloc[:,-1]

# %%
ss = StandardScaler()
ss.fit_transform(input_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10760\855206845.py in ?()
#       1 ss = StandardScaler()
# ----> 2 ss.fit_transform(input_data)
#
# D:\Deep_Learning_WS_Cube_Tech\tf_env\lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# D:\Deep_Learning_WS_Cube_Tech\tf_env\lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     890                 )
#     891
#     892         if y is None:
#     893             # fit method of arity 1 (unsupervised transformation)
# --> 894             return self.fit(X, **fit_params).transform(X)
#     895         else:
#     896             # fit method of arity 2 (supervised transformation)
#     897             return self.fit(X, y, **fit_params).transform(X)
#
# D:\Deep_Learning_WS_Cube_Tech\tf_env\lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     903             Fitted scaler.
#     904         """
#     905         # Reset internal state before fitting
#     906         self._reset()
# --> 907         return self.partial_fit(X, y, sample_weight)
#
# D:\Deep_Learning_WS_Cube_Tech\tf_env\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# D:\Deep_Learning_WS_Cube_Tech\tf_env\lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     939         self : object
#     940             Fitted scaler.
#     941         """
#     942         first_call = not hasattr(self, "n_samples_seen_")
# --> 943         X = validate_data(
#     944             self,
#     945             X,
#     946             accept_sparse=("csr", "csc"),
#
# D:\Deep_Learning_WS_Cube_Tech\tf_env\lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2950             out = y
#    2951         else:
#    2952             out = X, y
#    2953     elif not no_val_X and no_val_y:
# -> 2954         out = check_array(X, input_name="X", **check_params)
#    2955     elif no_val_X and not no_val_y:
#    2956         out = _check_y(y, **check_params)
#    2957     else:
#
# D:\Deep_Learning_WS_Cube_Tech\tf_env\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050                         )
#    1051                     array = xp.astype(array, dtype, copy=False)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#    1056                     "Complex data not supported\n{}\n".format(array)
#    1057                 ) from complex_warning
#
# D:\Deep_Learning_WS_Cube_Tech\tf_env\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     753         # Use NumPy API to support order
#     754         if copy is True:
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#     759         # At this point array is a NumPy ndarray. We convert it to an array
#     760         # container that is consistent with the input's namespace.
#
# D:\Deep_Learning_WS_Cube_Tech\tf_env\lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: 'Hargrave'

# %% [markdown]
# # Solve error

# %%
num_cols = ['CreditScore','Age','Tenure','Balance','NumOfProducts','HasCrCard',
            'IsActiveMember','EstimatedSalary']
cat_cols = ['Surname','Geography','Gender']

# %%
input_data = dataset[num_cols]
output_data = dataset.iloc[:,-1]

# %%
ss = StandardScaler()
ss.fit_transform(input_data)
# Out:
# array([[-0.32622142,  0.29351742, -1.04175968, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [-0.44003595,  0.19816383, -1.38753759, ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-1.53679418,  0.29351742,  1.03290776, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [ 0.60498839, -0.27860412,  0.68712986, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [ 1.25683526,  0.29351742, -0.69598177, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [ 1.46377078, -1.04143285, -0.35020386, ...,  0.64609167,
#         -1.03067011, -1.07636976]], shape=(10000, 8))

# %%
input_data = pd.DataFrame(ss.fit_transform(input_data), columns= input_data.columns)

# %%
input_data
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0       -0.326221  0.293517 -1.041760 -1.225848      -0.911583   0.646092
# 1       -0.440036  0.198164 -1.387538  0.117350      -0.911583  -1.547768
# 2       -1.536794  0.293517  1.032908  1.333053       2.527057   0.646092
# 3        0.501521  0.007457 -1.387538 -1.225848       0.807737  -1.547768
# 4        2.063884  0.388871 -1.041760  0.785728      -0.911583   0.646092
# ...           ...       ...       ...       ...            ...        ...
# 9995     1.246488  0.007457 -0.004426 -1.225848       0.807737   0.646092
# 9996    -1.391939 -0.373958  1.724464 -0.306379      -0.911583   0.646092
# 9997     0.604988 -0.278604  0.687130 -1.225848      -0.911583  -1.547768
# 9998     1.256835  0.293517 -0.695982 -0.022608       0.807737   0.646092
# 9999     1.463771 -1.041433 -0.350204  0.859965      -0.911583   0.646092
#
#       IsActiveMember  EstimatedSalary
# 0           0.970243         0.021886
# 1           0.970243         0.216534
# 2          -1.030670         0.240687
# 3          -1.030670        -0.108918
# 4           0.970243        -0.365276
# ...              ...              ...
# 9995       -1.030670        -0.066419
# 9996        0.970243         0.027988
# 9997        0.970243        -1.008643
# 9998       -1.030670        -0.125231
# 9999       -1.030670        -1.076370
#
# [10000 rows x 8 columns]

# %%
input_data.shape
# Out:
# (10000, 8)

# %%
x_train, x_test, y_train, y_test = train_test_split(input_data, output_data, test_size = 0.2, random_state = 10)

# %%
x_train.shape
# Out:
# (8000, 8)

# %%
x_test.head(1)
# Out:
#      CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 937     2.063884  0.484225 -0.004426  0.835324      -0.911583  -1.547768
#
#      IsActiveMember  EstimatedSalary
# 937        0.970243         1.234723

# %%
import tensorflow

# %%
# import sys
# !{sys.executable} -m pip install tensorflow
# !{sys.executable} -m pip install keras

# %%
from keras.layers import Dense
from keras.models import Sequential

# %%
from keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
from keras.regularizers import L2

# %%
from keras.layers import BatchNormalization

# %%
from keras.layers import Dropout

# %%
ann = Sequential()

# %%
# warining
# ann.add(Dense(6 ,input_dim = 8, activation="relu"))
# ann.add(Dense(4, activation="relu"))
# ann.add(Dense(2, activation="relu"))
# ann.add(Dense(1, activation="sigmoid"))

# %%
# Correct without regularization
# # recommended
# from keras.layers import Dense, Input

# # First layer with Input
# ann.add(Input(shape=(8,)))   # 8 features as input
# ann.add(Dense(6, activation="relu"))

# # Hidden layers
# ann.add(Dense(4, activation="relu"))
# ann.add(Dense(2, activation="relu"))

# # Output layer
# ann.add(Dense(1, activation="sigmoid"))

# %%
# # recommended with normal regularization
# from keras.layers import Dense, Input

# # First layer with Input
# ann.add(Input(shape=(8,)))   # 8 features as input
# ann.add(Dense(6, activation="relu", kernel_regularizer=L2(l2=0.01)))

# # Hidden layers
# ann.add(Dense(4, activation="relu", kernel_regularizer=L2(l2=0.01)))
# ann.add(Dense(2, activation="relu", kernel_regularizer=L2(l2=0.01)))

# # Output layer
# ann.add(Dense(1, activation="sigmoid"))

# %%
# # recommended with batch regularization
# from keras.layers import Dense, Input

# # First layer with Input
# ann.add(Input(shape=(8,)))   # 8 features as input
# ann.add(Dense(6, activation="relu", kernel_regularizer=L2(l2=0.01)))
# ann.add(BatchNormalization())

# # Hidden layers
# ann.add(Dense(4, activation="relu", kernel_regularizer=L2(l2=0.01)))
# ann.add(BatchNormalization())
# ann.add(Dense(2, activation="relu", kernel_regularizer=L2(l2=0.01)))
# ann.add(BatchNormalization())

# # Output layer
# ann.add(Dense(1, activation="sigmoid"))

# %%
# recommended with Dropout
from keras.layers import Dense, Input

# First layer with Input
ann.add(Input(shape=(8,)))   # 8 features as input
ann.add(Dense(6, activation="relu", kernel_regularizer=L2(l2=0.01)))
# ann.add(Dropout(0.5))

# Hidden layers
ann.add(Dense(4, activation="relu", kernel_regularizer=L2(l2=0.01)))
# ann.add(Dropout(0.5))
ann.add(Dense(2, activation="relu", kernel_regularizer=L2(l2=0.01)))
ann.add(Dropout(0.3))

# Output layer
ann.add(Dense(1, activation="sigmoid"))

# %%
ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# ann.fit(x_train, y_train, batch_size=100, epochs=50, validation_data=(x_test, y_test)) # This is correct without callbacks
# ann.fit(x_train, y_train, batch_size=100, epochs=50, validation_data=(x_test, y_test), callbacks=EarlyStopping) # Callbaskcs error

# %%
callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True)
]

# %%
ann.fit(x_train, y_train, batch_size=100, epochs=50, validation_data=(x_test, y_test), callbacks=callbacks)
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7753 - loss: 0.6823 - val_accuracy: 0.7890 - val_loss: 0.6363
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7981 - loss: 0.6246 - val_accuracy: 0.7890 - val_loss: 0.5849
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.5878 - val_accuracy: 0.7890 - val_loss: 0.5534
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.5602 - val_accuracy: 0.7890 - val_loss: 0.5325
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7981 - loss: 0.5381 - val_accuracy: 0.7890 - val_loss: 0.5184
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.5257 - val_accuracy: 0.7890 - val_loss: 0.5093
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.5137 - val_accuracy: 0.7890 - val_loss: 0.5022
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7981 - loss: 0.5121 - val_accuracy: 0.7890 - val_loss: 0.4970
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.5012 - val_accuracy: 0.7890 - val_loss: 0.4928
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7981 - loss: 0.5006 - val_accuracy: 0.7890 - val_loss: 0.4891
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4987 - val_accuracy: 0.7890 - val_loss: 0.4868
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4944 - val_accuracy: 0.7890 - val_loss: 0.4841
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7981 - loss: 0.4936 - val_accuracy: 0.7890 - val_loss: 0.4828
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4892 - val_accuracy: 0.7890 - val_loss: 0.4818
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4862 - val_accuracy: 0.7890 - val_loss: 0.4795
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4840 - val_accuracy: 0.7890 - val_loss: 0.4783
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7981 - loss: 0.4894 - val_accuracy: 0.7890 - val_loss: 0.4773
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7981 - loss: 0.4819 - val_accuracy: 0.7890 - val_loss: 0.4752
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4805 - val_accuracy: 0.7890 - val_loss: 0.4734
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4768 - val_accuracy: 0.7890 - val_loss: 0.4708
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4772 - val_accuracy: 0.7890 - val_loss: 0.4687
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7981 - loss: 0.4755 - val_accuracy: 0.7890 - val_loss: 0.4668
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4718 - val_accuracy: 0.7890 - val_loss: 0.4653
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4715 - val_accuracy: 0.7890 - val_loss: 0.4642
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4714 - val_accuracy: 0.7890 - val_loss: 0.4633
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7981 - loss: 0.4671 - val_accuracy: 0.7890 - val_loss: 0.4622
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4686 - val_accuracy: 0.7890 - val_loss: 0.4615
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7981 - loss: 0.4686 - val_accuracy: 0.7890 - val_loss: 0.4600
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4666 - val_accuracy: 0.7890 - val_loss: 0.4598
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4658 - val_accuracy: 0.7890 - val_loss: 0.4581
# Epoch 31/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4647 - val_accuracy: 0.7890 - val_loss: 0.4575
# Epoch 32/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7981 - loss: 0.4668 - val_accuracy: 0.7890 - val_loss: 0.4581
# Epoch 33/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4681 - val_accuracy: 0.7890 - val_loss: 0.4567
# Epoch 34/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4617 - val_accuracy: 0.7890 - val_loss: 0.4554
# Epoch 35/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4661 - val_accuracy: 0.7890 - val_loss: 0.4562
# Epoch 36/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4626 - val_accuracy: 0.7890 - val_loss: 0.4550
# Epoch 37/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4611 - val_accuracy: 0.7890 - val_loss: 0.4551
# Epoch 38/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4637 - val_accuracy: 0.7890 - val_loss: 0.4538
# Epoch 39/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7981 - loss: 0.4642 - val_accuracy: 0.7890 - val_loss: 0.4529
# Epoch 40/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7981 - loss: 0.4580 - val_accuracy: 0.7890 - val_loss: 0.4528
# Epoch 41/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4604 - val_accuracy: 0.7890 - val_loss: 0.4516
# Epoch 42/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7981 - loss: 0.4598 - val_accuracy: 0.7890 - val_loss: 0.4515
# Epoch 43/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4588 - val_accuracy: 0.7890 - val_loss: 0.4501
# Epoch 44/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4592 - val_accuracy: 0.7890 - val_loss: 0.4497
# Epoch 45/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4574 - val_accuracy: 0.7890 - val_loss: 0.4490
# Epoch 46/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4560 - val_accuracy: 0.7890 - val_loss: 0.4488
# Epoch 47/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4570 - val_accuracy: 0.7890 - val_loss: 0.4485
# Epoch 48/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4586 - val_accuracy: 0.7890 - val_loss: 0.4480
# Epoch 49/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4570 - val_accuracy: 0.7890 - val_loss: 0.4483
# Epoch 50/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7981 - loss: 0.4580 - val_accuracy: 0.7890 - val_loss: 0.4474

# %%
# ann.history.history

# %%
train_accuracy = ann.history.history["accuracy"]
test_accuracy = ann.history.history["val_accuracy"]

# %%
len(test_accuracy)
# Out:
# 50

# %%
plt.plot([i for i in range(1, 51)], train_accuracy)
plt.plot([i for i in range(1, 51)], test_accuracy, c='red')
plt.show()

# %%
prd = ann.predict(x_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
prd
# Out:
# array([[0.24562317],
#        [0.29746822],
#        [0.37417302],
#        ...,
#        [0.20869626],
#        [0.38412857],
#        [0.38412857]], shape=(2000, 1), dtype=float32)

# %%
prd_data = []
for i in prd:
    if i[0] > 0.5:
        prd_data.append(1)
    else:
        prd_data.append(0)

# %%
# prd_data

# %%
prd1 = ann.predict(x_train)
prd_data1 = []
for i in prd1:
    if i[0] > 0.5:
        prd_data1.append(1)
    else:
        prd_data1.append(0)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# prd_data1

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, prd_data) * 100
# Out:
# 78.9

# %%
accuracy_score(y_train, prd_data1) * 100
# Out:
# 79.8125

# %%
# Testing New data
import numpy as np
x = np.array([[-0.564197,-0.660018,-0.695982,0.324119,
               0.807737,-1.547768,-1.03067,-1.013811]])
prdn = ann.predict(x) #Accept 1/8 array
prd_datan = []
for i in prdn:
    if i[0] > 0.5:
        prd_datan.append(1)
    else:
        prd_datan.append(0)
prd_datan
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# [0]

# %%
y_test.head(1)
# Out:
# 937    0
# Name: Exited, dtype: int64
